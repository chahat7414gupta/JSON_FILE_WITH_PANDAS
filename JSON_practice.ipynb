# %% [markdown]
# <a href="https://colab.research.google.com/github/chahat7414gupta/JSON_FILE_WITH_PANDAS/blob/main/JSON_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
my_data=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(my_data)
# Out:
# list

# %%
len(my_data)
# Out:
# 1

# %%
my_data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(my_data)
# Out:
# list

# %%
my_data_1=my_data[0]

# %%
my_data_1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
my_data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      675 non-null    object
#  1   Player  675 non-null    object
#  2   Pos     675 non-null    object
#  3   Age     675 non-null    object
#  4   Tm      675 non-null    object
#  5   G       675 non-null    object
#  6   GS      675 non-null    object
#  7   MP      675 non-null    object
#  8   FG      675 non-null    object
#  9   FGA     675 non-null    object
#  10  FG%     673 non-null    object
#  11  3P      675 non-null    object
#  12  3PA     675 non-null    object
#  13  3P%     594 non-null    object
#  14  2P      675 non-null    object
#  15  2PA     675 non-null    object
#  16  2P%     671 non-null    object
#  17  eFG%    673 non-null    object
#  18  FT      675 non-null    object
#  19  FTA     675 non-null    object
#  20  FT%     650 non-null    object
#  21  ORB     675 non-null    object
#  22  DRB     675 non-null    object
#  23  TRB     675 non-null    object
#  24  AST     675 non-null    object
#  25  STL     675 non-null    object
#  26  BLK     675 non-null    object
#  27  TOV     675 non-null    object
#  28  PF      675 non-null    object
#  29  PTS     675 non-null    object
# dtypes: object(30)
# memory usage: 158.3+ KB

# %%
my_data_1.to_csv('pa.csv',index=False)

# %%
ls
# Out:
# pa.csv  sample_data/

# %%
l=pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
l
# Out:
# [                Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
#  0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
#  1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
#  2            S Aravind  2015-2015    1    -   0     -    -      - -100.00   -
#  3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   60.00   -
#  4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
#  ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
#  97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
#  98   Washington Sundar  2017-2023   35   14   4   107   50  10.70  152.85   -
#  99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  175.76   3
#  100           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
#  101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#       50  0
#  0     -  -
#  1     -  -
#  2     -  -
#  3     -  -
#  4     -  -
#  ..   .. ..
#  97    -  -
#  98    1  4
#  99   13  3
#  100   -  -
#  101   8  1
#
#  [102 rows x 12 columns]]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
#                 Player       Span  Mat Inns  NO  Runs   HS    Ave      SR 100  \
# 0           AB Agarkar  2006-2007    4    2   0    15   14   7.50  136.36   -
# 1             KK Ahmed  2018-2019   14    1   1     1   1*      -  100.00   -
# 2            S Aravind  2015-2015    1    -   0     -    -      - -100.00   -
# 3       Arshdeep Singh  2022-2023   26    5   5     6   2*      -   60.00   -
# 4             R Ashwin  2010-2022   65   19  12   184  31*  26.28  115.00   -
# ..                 ...        ...  ...  ...  ..   ...  ...    ...     ...  ..
# 97       R Vinay Kumar  2010-2013    9    1   1     2   2*      -   50.00   -
# 98   Washington Sundar  2017-2023   35   14   4   107   50  10.70  152.85   -
# 99            SA Yadav  2021-2023   48   46  10  1675  117  46.52  175.76   3
# 100           UT Yadav  2012-2022    9    2   1    22  20*  22.00  104.76   -
# 101       Yuvraj Singh  2007-2017   58   51   9  1177  77*  28.02  136.38   -
#
#      50  0
# 0     -  -
# 1     -  -
# 2     -  -
# 3     -  -
# 4     -  -
# ..   .. ..
# 97    -  -
# 98    1  4
# 99   13  3
# 100   -  -
# 101   8  1
#
# [102 rows x 12 columns]

# %%
l1=l[0]

# %%
l1.to_csv('la.csv',index=False)

# %%
ls
# Out:
# la.csv  pa.csv  sample_data/

# %%
import json

# %%
d ="""{"name" : ["Sudhanshu kumar" , "chahat","gupta"], 
"email id " : ["sskumar@gmail.com","chahat.gupta1212@gmail.com","ranjanadhps@gmail.com"],
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
d1 ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
result1=json.loads(d1)

# %%
pd.DataFrame(result1)
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %% [markdown]
# In this we have same number of attributes in the dict , but in other case we don't have same number of arrray thats it will repeat the one attritube to the other rows

# %%
result=json.loads(d)

# %%
result
# Out:
# {'name': ['Sudhanshu kumar', 'chahat', 'gupta'],
#  'email id ': ['sskumar@gmail.com',
#   'chahat.gupta1212@gmail.com',
#   'ranjanadhps@gmail.com'],
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#               name                   email id  tech   plateform
# 0  Sudhanshu kumar           sskumar@gmail.com   ML  techneuron
# 1           chahat  chahat.gupta1212@gmail.com   DL  kidsneuron
# 2            gupta       ranjanadhps@gmail.com   CV     ineuron

# %% [markdown]
# If i called only feature from the dict file[d] it will show me the diiferent -different patterns let's try this one:-

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
d1 = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
pd.DataFrame(d1)
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# tcuTemperatureAverage              D
# coolantMin                         D
# coolantMax                         D
# coolantAverage                     D
# packetStartLocal                   D
# tripStartLocal                     D
# milIndicator                       D
# monitorsNotReady                   D
# imei                               D
# gatewayTs                          D
# diagnosticTroubleCodeData          D
# diagnosticPidData                  D
# iwrapVer                           D
# sourceSystem                       D
# configVer                          D
# oemName                            D
# unitType                           D
# cpVer                              D
# igpsVer                            D
# messageType                        D
# pomVer                             D
# headerVer                          D
# timestamp                          D
# deviceType                         D
# visorVer                           D
# transactionId                      D
# deviceSerialNo                     D
# subOrganization                    D
# organization                       D
# operation                          D
#
#                                                                         data  \
# checkEngineLightFlag                                                       F
# batteryVoltageStableTime                                                   0
# batteryVoltageStable                                                       0
# batteryVoltageOff                                                      12.42
# batteryCrankParamTN                                                    -0.08
# batteryCrankParamVN                                                     0.00
# batteryCrankParamTP                                                    -0.08
# batteryCrankParamVP                                                     0.00
# batteryCrankParamTT                                                 -0.00008
# batteryCrankParamV0                                                     0.00
# batteryVoltageMaxOn                                                    13.05
# batteryVoltageMinOn                                                    12.97
# batteryVoltageMaxOff                                                   12.46
# batteryVoltageMinOff                                                   12.36
# batteryVoltageOnAverage                                                13.02
# engineLoadMax                                                             84
# engineLoadAverage                                                      39.98
# rpmMax                                                                  3487
# rpmAverage                                                           1431.29
# gpsSpeedAverage                                                        21.99
# vssMax                                                                 53.44
# vssAverage                                                             23.06
# tcuTemperatureMin                                                      82.40
# tcuTemperatureMax                                                     109.40
# tcuTemperatureAverage                                                 104.87
# coolantMin                                                            158.00
# coolantMax                                                            188.60
# coolantAverage                                                        180.20
# packetStartLocal                                               1508143346000
# tripStartLocal                                                 1508143346000
# milIndicator                                                               F
# monitorsNotReady                                                           0
# imei                                                                60DF5417
# gatewayTs                                                      1515613306592
# diagnosticTroubleCodeData                                                 []
# diagnosticPidData          [[64768, 47, 100], [64768, 1, 517376], [64800,...
# iwrapVer                                                                 NaN
# sourceSystem                                                             NaN
# configVer                                                                NaN
# oemName                                                                  NaN
# unitType                                                                 NaN
# cpVer                                                                    NaN
# igpsVer                                                                  NaN
# messageType                                                              NaN
# pomVer                                                                   NaN
# headerVer                                                                NaN
# timestamp                                                                NaN
# deviceType                                                               NaN
# visorVer                                                                 NaN
# transactionId                                                            NaN
# deviceSerialNo                                                           NaN
# subOrganization                                                          NaN
# organization                                                             NaN
# operation                                                                NaN
#
#                                                          header
# checkEngineLightFlag                                        NaN
# batteryVoltageStableTime                                    NaN
# batteryVoltageStable                                        NaN
# batteryVoltageOff                                           NaN
# batteryCrankParamTN                                         NaN
# batteryCrankParamVN                                         NaN
# batteryCrankParamTP                                         NaN
# batteryCrankParamVP                                         NaN
# batteryCrankParamTT                                         NaN
# batteryCrankParamV0                                         NaN
# batteryVoltageMaxOn                                         NaN
# batteryVoltageMinOn                                         NaN
# batteryVoltageMaxOff                                        NaN
# batteryVoltageMinOff                                        NaN
# batteryVoltageOnAverage                                     NaN
# engineLoadMax                                               NaN
# engineLoadAverage                                           NaN
# rpmMax                                                      NaN
# rpmAverage                                                  NaN
# gpsSpeedAverage                                             NaN
# vssMax                                                      NaN
# vssAverage                                                  NaN
# tcuTemperatureMin                                           NaN
# tcuTemperatureMax                                           NaN
# tcuTemperatureAverage                                       NaN
# coolantMin                                                  NaN
# coolantMax                                                  NaN
# coolantAverage                                              NaN
# packetStartLocal                                            NaN
# tripStartLocal                                              NaN
# milIndicator                                                NaN
# monitorsNotReady                                            NaN
# imei                                                   60DF5417
# gatewayTs                                                   NaN
# diagnosticTroubleCodeData                                   NaN
# diagnosticPidData                                           NaN
# iwrapVer                                                 1.9.20
# sourceSystem                                                CDP
# configVer                                                   1.1
# oemName                                                     HUM
# unitType                                                      0
# cpVer                                                  7.50.1.9
# igpsVer                                                   1.3.7
# messageType                                        Notification
# pomVer                                                      1.0
# headerVer                                                    V6
# timestamp                                                     0
# deviceType                                              InDrive
# visorVer                                                 1.4.35
# transactionId              53098471-7787-4160-94b3-cd69dcc70416
# deviceSerialNo                                         60DF5417
# subOrganization                                             HUM
# organization                                                HUM
# operation                                          Notification

# %%
d2=d1['data']

# %%
d2
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
del d2['diagnosticTroubleCodeData']

# %%
d2
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
pd.DataFrame(d2)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
url='https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data=pd.read_json(url)

# %%
data

# %%
 import requests

# %%
url='https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
d1=data.json()

# %%
d1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52908',
#   'id': 1682773349,
#   'node_id': 'I_kwDOAA0YD85kTRVl',
#   'number': 52908,
#   'title': 'BUG: date_range fails DST transition between start and end.',
#   'user': {'login': 'doctrino',
#    'id': 60234212,
#    'node_id': 'MDQ6VXNlcjYwMjM0MjEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60234212?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/doctrino',
#    'html_url': 'https://github.com/doctrino',
#    'followers_url': 'https://api.github.com/users/doctrino/followers',
#    'following_url': 'https://api.github.com/users/doctrino/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/doctrino/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/doctrino/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/doctrino/subscriptions',
#    'organizations_url': 'https://api.github.com/users/doctrino/orgs',
#    'repos_url': 'https://api.github.com/users/doctrino/repos',
#    'events_url': 'https://api.github.com/users/doctrino/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/doctrino/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-25T09:19:52Z',
#   'updated_at': '2023-04-25T09:19:52Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\npd.date_range("1916-08-01", "1916-12-01", tz="Europe/Oslo", freq="1MS", ambiguous=True)\n```\n\n\n### Issue Description\n\nThe code above produced the following error\r\n```\r\n  File "...\\pandas\\core\\indexes\\datetimes.py", line 945, in date_range\r\n    dtarr = DatetimeArray._generate_range(\r\n  File "...\\pandas\\core\\arrays\\datetimes.py", line 460, in _generate_range\r\n    i8values = tzconversion.tz_localize_to_utc(\r\n  File "pandas\\_libs\\tslibs\\tzconversion.pyx", line 362, in pandas._libs.tslibs.tzconversion.tz_localize_to_utc\r\npytz.exceptions.AmbiguousTimeError: Cannot infer dst time from 1916-10-01 00:00:00, try using the \'ambiguous\' argument\r\n```\n\n### Expected Behavior\n\n```python\r\n>>> pd.date_range("1916-08-01", "1916-12-01", tz="Europe/Oslo", freq="1MS", ambiguous=True)\r\nDatetimeIndex([\'1916-08-01 00:00:00+02:00\', 1916-09-01 00:00:00+02:00\',\r\n               1916-10-01 00:00:00+02:00\', 1916-11-01 00:00:00+01:00\',\r\n                1916-12-01 00:00:00+01:00],\r\n              dtype=\'datetime64[ns, Europe/Oslo]\', length=5, freq=\'1MS\')\r\n```\r\n\r\nThe problem is that 1916-10-01 00:00:00 is an ambiguous in Europe/Oslo as this is the DST transition, thus there are two possible UTC times  `1916-10-01 00:00:00+02:00` and `1916-10-01 00:00:00+01:00`. The ambiguous argument to `date_range` is not utilized.  \r\n\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 37ea63d540fd27274cad6585082c91b1283f963d\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.22621\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 165 Stepping 2, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\npandas           : 2.0.1\r\nnumpy            : 1.24.2\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.6.1\r\npip              : 23.0.1\r\nCython           : None\r\npytest           : 7.3.0\r\nhypothesis       : None\r\nsphinx           : 5.3.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.10.1\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52906',
#   'id': 1682243387,
#   'node_id': 'PR_kwDOAA0YD85PDhjc',
#   'number': 52906,
#   'title': 'DEPS: Address numpy deprecation of len 1 arrays assignment',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Required and optional dependencies'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-25T00:43:30Z',
#   'updated_at': '2023-04-25T00:43:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52906',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52906',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52906.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52906.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #52853 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52905',
#   'id': 1682045021,
#   'node_id': 'PR_kwDOAA0YD85PC2Tr',
#   'number': 52905,
#   'title': 'DOC: Remove versionadded/changed for 1.1.0',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T21:05:51Z',
#   'updated_at': '2023-04-25T00:49:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52905',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52905',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52905.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52905.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nremoved 1.0 and earlier for 2.0, so can remove 1.1.0 for 2.1 I guess',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52904',
#   'id': 1682019729,
#   'node_id': 'I_kwDOAA0YD85kQZWR',
#   'number': 52904,
#   'title': 'ENH: Support pyarrow timestamps in merge_asof',
#   'user': {'login': 'bphillips-exos',
#    'id': 56549508,
#    'node_id': 'MDQ6VXNlcjU2NTQ5NTA4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56549508?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bphillips-exos',
#    'html_url': 'https://github.com/bphillips-exos',
#    'followers_url': 'https://api.github.com/users/bphillips-exos/followers',
#    'following_url': 'https://api.github.com/users/bphillips-exos/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bphillips-exos/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bphillips-exos/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bphillips-exos/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bphillips-exos/orgs',
#    'repos_url': 'https://api.github.com/users/bphillips-exos/repos',
#    'events_url': 'https://api.github.com/users/bphillips-exos/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bphillips-exos/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T20:50:42Z',
#   'updated_at': '2023-04-25T02:29:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [X] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nI would like to be able to use pyarrow timestamp dtypes as the merge column/index in merge_asof operations.\r\n\r\nThis code currently raises `KeyError: 'timestamp[ns][pyarrow]_t|object'`\r\n```python\r\nimport pandas as pd\r\nimport pyarrow as pa\r\n\r\ndf = pd.DataFrame(\r\n    index=pd.Series([0, 1], dtype=pd.ArrowDtype(pa.timestamp('ns'))),\r\n    data={'value': pd.Series(['a', 'b'], dtype=pd.ArrowDtype(pa.string()))},\r\n)\r\n\r\npd.merge_asof(df, df, left_index=True, right_index=True)\r\n```\n\n### Feature Description\n\nThere would be no changes to user facing behavior, I'm not sure about the internal complexity involved in implementation. \n\n### Alternative Solutions\n\nThe current numpy datetime dtype can be used in merge_asof operations, but when your dataframe is read from parquet files this can be an expensive translation step. \n\n### Additional Context\n\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52903',
#   'id': 1681993470,
#   'node_id': 'PR_kwDOAA0YD85PCqzp',
#   'number': 52903,
#   'title': 'BUG: Fix pandas._libs.json __name__',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 26,
#    'closed_issues': 434,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-04-25T00:52:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-04-24T20:34:47Z',
#   'updated_at': '2023-04-24T20:34:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52903',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52903',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52903.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52903.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52898 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52902',
#   'id': 1681962231,
#   'node_id': 'PR_kwDOAA0YD85PCj0R',
#   'number': 52902,
#   'title': 'BUG: date_range with DateOffset with nanoseconds',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False,
#     'description': 'DateOffsets'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 26,
#    'closed_issues': 434,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-04-25T00:52:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-04-24T20:16:11Z',
#   'updated_at': '2023-04-24T22:28:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52902',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52902',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52902.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52902.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46877 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52899',
#   'id': 1681787303,
#   'node_id': 'I_kwDOAA0YD85kPgmn',
#   'number': 52899,
#   'title': '`pyarrow` uses `is_sparse()`, which is deprecated in development code, causing warnings on I/O routines with pandas',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-24T18:11:20Z',
#   'updated_at': '2023-04-25T02:29:51Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'See tests from pandas-stubs:  https://github.com/pandas-dev/pandas-stubs/actions/runs/4789491663/jobs/8517432719\r\n\r\n`to_feather()`, `to_orc()` and `to_parquet()` call pyarrow, which is using `api.is_sparse()`, which is now marked as deprecated.\r\n\r\nCreated pandas-stubs issue:\r\nhttps://github.com/pandas-dev/pandas-stubs/issues/657\r\n\r\nComment here by @mroeschke in https://github.com/pandas-dev/pandas/pull/52642#discussion_r1167150428 indicates it is reasonable for pyarrow to change their code - checking if we have created an issue there, and whether we should do something about the warning that a user would see if using those methods from pandas.\r\n\r\n@jbrockmendel \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52898',
#   'id': 1681783699,
#   'node_id': 'I_kwDOAA0YD85kPfuT',
#   'number': 52898,
#   'title': 'BUG: Module `pandas._libs.json` has incorrect `__name__` attribute',
#   'user': {'login': 'shwina',
#    'id': 3190405,
#    'node_id': 'MDQ6VXNlcjMxOTA0MDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3190405?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shwina',
#    'html_url': 'https://github.com/shwina',
#    'followers_url': 'https://api.github.com/users/shwina/followers',
#    'following_url': 'https://api.github.com/users/shwina/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shwina/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shwina/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shwina/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shwina/orgs',
#    'repos_url': 'https://api.github.com/users/shwina/repos',
#    'events_url': 'https://api.github.com/users/shwina/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shwina/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-24T18:08:44Z',
#   'updated_at': '2023-04-25T09:19:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n>>> import pandas as pd\r\npd>>> pd.__version__\r\n'2.0.0'\r\n>>> pd._libs.json.__name__\r\n'_libjson'\r\n>>> pd._libs.missing.__name__\r\n'pandas._libs.missing'\n```\n\n\n### Issue Description\n\nThe `__name__` attribute for the `pandas._libs.json` is set to `_libjson` [here](https://github.com/pandas-dev/pandas/blob/main/pandas/_libs/src/ujson/python/ujson.c#L86).\r\n\r\nThe [Python docs](https://docs.python.org/3/reference/import.html#name__) say that `__name__` should be set to the fully qualified name of the module, which I would expect to be `'pandas._libs.json'`.\r\n\r\nIn the code example above, you can see that other Pandas C-extensions like `pd._libs.missing` have the correct `__name__` attribute set.\r\n\n\n### Expected Behavior\n\n`__name__` should be set to the fully qualified name of the module, which I would expect to be `'pandas._libs.json'`.\n\n### Installed Versions\n\n2",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52897',
#   'id': 1681654482,
#   'node_id': 'PR_kwDOAA0YD85PBhHr',
#   'number': 52897,
#   'title': 'Fixes Incompatible return value type in pandas/core/generic.py',
#   'user': {'login': 'bunardsheng',
#    'id': 84961555,
#    'node_id': 'MDQ6VXNlcjg0OTYxNTU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84961555?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bunardsheng',
#    'html_url': 'https://github.com/bunardsheng',
#    'followers_url': 'https://api.github.com/users/bunardsheng/followers',
#    'following_url': 'https://api.github.com/users/bunardsheng/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bunardsheng/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bunardsheng/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bunardsheng/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bunardsheng/orgs',
#    'repos_url': 'https://api.github.com/users/bunardsheng/repos',
#    'events_url': 'https://api.github.com/users/bunardsheng/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bunardsheng/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T16:35:49Z',
#   'updated_at': '2023-04-24T20:50:00Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52897',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52897',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52897.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52897.patch',
#    'merged_at': None},
#   'body': '- Contributes to issue #37715 (https://github.com/pandas-dev/pandas/issues/37715)\r\n- Casts 64-bit signed integer to int value\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52895',
#   'id': 1681362435,
#   'node_id': 'I_kwDOAA0YD85kN44D',
#   'number': 52895,
#   'title': 'BUG: int Overflow with DateFormatter',
#   'user': {'login': 'joooeey',
#    'id': 28426758,
#    'node_id': 'MDQ6VXNlcjI4NDI2NzU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28426758?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joooeey',
#    'html_url': 'https://github.com/joooeey',
#    'followers_url': 'https://api.github.com/users/joooeey/followers',
#    'following_url': 'https://api.github.com/users/joooeey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/joooeey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/joooeey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/joooeey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/joooeey/orgs',
#    'repos_url': 'https://api.github.com/users/joooeey/repos',
#    'events_url': 'https://api.github.com/users/joooeey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/joooeey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 3059772828,
#     'node_id': 'MDU6TGFiZWwzMDU5NzcyODI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/datetime.date',
#     'name': 'datetime.date',
#     'color': 'bfd4f2',
#     'default': False,
#     'description': 'stdlib datetime.date support'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T14:08:02Z',
#   'updated_at': '2023-04-25T02:31:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport datetime as dt\r\nfrom matplotlib import dates\r\nimport pandas as pd\r\n\r\ndates.set_epoch("2023-01-01")  # suggested workaround doesn\'t help\r\nstart = dt.datetime(2022, 4, 4, 7)\r\nend = dt.datetime(2022, 4, 4, 16)\r\nindex = pd.date_range(start, end, freq="s")\r\ndf = pd.DataFrame(index=index)\r\ndf["col"] = 1\r\nax = df.plot()\r\nax.xaxis.set_major_formatter(dates.DateFormatter("%H:%M"))  # breaks\n```\n\n\n### Issue Description\n\nSee also:  #18348\r\n\r\nWhen setting a `matplotlib.dates.DateFormatter`, I get the following exception:\r\n```\r\nOverflowError: int too big to convert\r\n```\r\n\r\nFull Traceback:\r\n\r\n<details>\r\n\r\n```\r\nrunfile(\'/home/lukas/.config/spyder-py3/temp.py\', wdir=\'/home/lukas/.config/spyder-py3\')\r\n[autoreload of pandas.core.arrays.timedeltas failed: Traceback (most recent call last):\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 273, in check\r\n    superreload(m, reload, self.old_objects)\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 471, in superreload\r\n    module = reload(module)\r\n             ^^^^^^^^^^^^^^\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/importlib/__init__.py", line 169, in reload\r\n    _bootstrap._exec(spec, module)\r\n  File "<frozen importlib._bootstrap>", line 621, in _exec\r\n  File "<frozen importlib._bootstrap_external>", line 940, in exec_module\r\n  File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/pandas/core/arrays/timedeltas.py", line 34, in <module>\r\n    from pandas._libs.tslibs.fields import (\r\nImportError: cannot import name \'get_timedelta_days\' from \'pandas._libs.tslibs.fields\' (/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/pandas/_libs/tslibs/fields.cpython-311-x86_64-linux-gnu.so)\r\n]\r\n[autoreload of pandas._testing failed: Traceback (most recent call last):\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 273, in check\r\n    superreload(m, reload, self.old_objects)\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 471, in superreload\r\n    module = reload(module)\r\n             ^^^^^^^^^^^^^^\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/importlib/__init__.py", line 169, in reload\r\n    _bootstrap._exec(spec, module)\r\n  File "<frozen importlib._bootstrap>", line 621, in _exec\r\n  File "<frozen importlib._bootstrap_external>", line 940, in exec_module\r\n  File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/pandas/_testing/__init__.py", line 914, in <module>\r\n    cython_table = pd.core.common._cython_table.items()\r\n                   ^^^^^^^^^^^^^^\r\nAttributeError: module \'pandas.core\' has no attribute \'common\'\r\n]\r\nError in callback <function _draw_all_if_interactive at 0x7f4dc0f96020> (for post_execute):\r\nTraceback (most recent call last):\r\n\r\n  File ~/mambaforge/envs/moma/lib/python3.11/site-packages/matplotlib/pyplot.py:120 in _draw_all_if_interactive\r\n    draw_all()\r\n\r\n  File ~/mambaforge/envs/moma/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132 in draw_all\r\n    manager.canvas.draw_idle()\r\n\r\n  File ~/mambaforge/envs/moma ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52894',
#   'id': 1681244130,
#   'node_id': 'PR_kwDOAA0YD85PAHZS',
#   'number': 52894,
#   'title': 'added typing IntervalClosedType where needed',
#   'user': {'login': 'gmollard',
#    'id': 22834092,
#    'node_id': 'MDQ6VXNlcjIyODM0MDky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22834092?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gmollard',
#    'html_url': 'https://github.com/gmollard',
#    'followers_url': 'https://api.github.com/users/gmollard/followers',
#    'following_url': 'https://api.github.com/users/gmollard/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gmollard/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gmollard/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gmollard/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gmollard/orgs',
#    'repos_url': 'https://api.github.com/users/gmollard/repos',
# ...
#     'gists_url': 'https://api.github.com/users/szczekulskij/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/szczekulskij/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/szczekulskij/subscriptions',
#     'organizations_url': 'https://api.github.com/users/szczekulskij/orgs',
#     'repos_url': 'https://api.github.com/users/szczekulskij/repos',
#     'events_url': 'https://api.github.com/users/szczekulskij/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/szczekulskij/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2023-04-22T15:08:14Z',
#   'updated_at': '2023-04-25T01:52:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '```\r\ndf = DataFrame({"a1": [0, 0, 1], "a2": [2, 3, 3], "b": [4, 5, 6]})\r\ndf = df.astype({"a1": "category", "a2": "category"})\r\ngb = df.groupby(by=["a1", "a2"], as_index=False, observed=False)\r\ngb.nunique()\r\n```\r\n\r\nraises `ValueError: Length of values (3) does not match length of index (4)`',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52848/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52848/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52840',
#   'id': 1679191992,
#   'node_id': 'PR_kwDOAA0YD85O5dWS',
#   'number': 52840,
#   'title': 'BUG: FloatingArray.__contains__(nan)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-21T22:48:55Z',
#   'updated_at': '2023-04-24T18:33:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52840',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52840',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52840.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52840.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nMore targeted version of #51378',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52839',
#   'id': 1679005068,
#   'node_id': 'PR_kwDOAA0YD85O40H-',
#   'number': 52839,
#   'title': 'DEPR: Series logical ops with different index coercing to bool',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric%20Operations',
#     'name': 'Numeric Operations',
#     'color': '006b75',
#     'default': False,
#     'description': 'Arithmetic, Comparison, and Logical operations'},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 26,
#    'closed_issues': 434,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-04-25T00:52:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2023-04-21T19:44:35Z',
#   'updated_at': '2023-04-24T20:38:34Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52839',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52839',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52839.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52839.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52500 (Replace xxxx with the GitHub issue number)\r\n- [x] closes #52538 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52836',
#   'id': 1678956012,
#   'node_id': 'PR_kwDOAA0YD85O4pih',
#   'number': 52836,
#   'title': 'PERF: Faster transposition of frames with masked arrays',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-21T18:53:59Z',
#   'updated_at': '2023-04-22T01:08:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52836',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52836',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52836.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52836.patch',
#    'merged_at': None},
#   'body': 'Faster transpose of dataframes with homogenous masked arrays. This also helps when doing reductions with `axis=1` as those currently transpose data before doing reductions.\r\n\r\nPerformance example:\r\n\r\n```python\r\nIn [1]:         import pandas as pd, numpy as np\r\n   ...:         values = np.random.randn(100000, 4)\r\n   ...:         values = values.astype(int)\r\n   ...:         df = pd.DataFrame(values).astype("Int64")\r\n>>> %timeit df.transpose()\r\n1.91 s ± 3.08 ms per loop  # main\r\n563 ms ± 2.48 ms per loop  # this PR\r\n```\r\n\r\nRunning `asv continuous -f 1.1 upstream/main HEAD -b reshape.ReshapeMaskedArrayDtype.time_transpose`:\r\n\r\n```\r\n       before           after         ratio\r\n     [c3f0aac1]       [43162428]\r\n     <master>         <cln_managers>\r\n-     13.5±0.06ms      1.82±0.01ms     0.14  reshape.ReshapeMaskedArrayDtype.time_transpose(\'Float64\')\r\n-     13.8±0.03ms      1.83±0.01ms     0.13  reshape.ReshapeMaskedArrayDtype.time_transpose(\'Int64\')\r\n\r\nSOME BENCHMARKS HAVE CHANGED SIGNIFICANTLY.\r\nPERFORMANCE INCREASED.\r\n```\r\n\r\nThere may be possible to improve performance when frames have a common masked dtype, I intend to look into that in a followup.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
d1[1]['user']['login']
# Out:
# 'mroeschke'

# %%
for i in range(len(d1)):
    print(d1[i]['user']['login'])
# Out:
# doctrino
# mroeschke
# phofl
# bphillips-exos
# mroeschke
# mroeschke
# Dr-Irv
# shwina
# bunardsheng
# joooeey
# gmollard
# datapythonista
# topper-123
# jiawei-zhang-a
# Masnan-306
# jinlixiao
# manjalc
# reddyrg1
# YifanChao
# phofl
# YifanChao
# jbrockmendel
# szczekulskij
# VomV
# phofl
# rhshadrach
# rhshadrach
# jbrockmendel
# mroeschke
# topper-123

# %%
d1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52908',
#   'id': 1682773349,
#   'node_id': 'I_kwDOAA0YD85kTRVl',
#   'number': 52908,
#   'title': 'BUG: date_range fails DST transition between start and end.',
#   'user': {'login': 'doctrino',
#    'id': 60234212,
#    'node_id': 'MDQ6VXNlcjYwMjM0MjEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60234212?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/doctrino',
#    'html_url': 'https://github.com/doctrino',
#    'followers_url': 'https://api.github.com/users/doctrino/followers',
#    'following_url': 'https://api.github.com/users/doctrino/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/doctrino/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/doctrino/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/doctrino/subscriptions',
#    'organizations_url': 'https://api.github.com/users/doctrino/orgs',
#    'repos_url': 'https://api.github.com/users/doctrino/repos',
#    'events_url': 'https://api.github.com/users/doctrino/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/doctrino/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-25T09:19:52Z',
#   'updated_at': '2023-04-25T09:19:52Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\npd.date_range("1916-08-01", "1916-12-01", tz="Europe/Oslo", freq="1MS", ambiguous=True)\n```\n\n\n### Issue Description\n\nThe code above produced the following error\r\n```\r\n  File "...\\pandas\\core\\indexes\\datetimes.py", line 945, in date_range\r\n    dtarr = DatetimeArray._generate_range(\r\n  File "...\\pandas\\core\\arrays\\datetimes.py", line 460, in _generate_range\r\n    i8values = tzconversion.tz_localize_to_utc(\r\n  File "pandas\\_libs\\tslibs\\tzconversion.pyx", line 362, in pandas._libs.tslibs.tzconversion.tz_localize_to_utc\r\npytz.exceptions.AmbiguousTimeError: Cannot infer dst time from 1916-10-01 00:00:00, try using the \'ambiguous\' argument\r\n```\n\n### Expected Behavior\n\n```python\r\n>>> pd.date_range("1916-08-01", "1916-12-01", tz="Europe/Oslo", freq="1MS", ambiguous=True)\r\nDatetimeIndex([\'1916-08-01 00:00:00+02:00\', 1916-09-01 00:00:00+02:00\',\r\n               1916-10-01 00:00:00+02:00\', 1916-11-01 00:00:00+01:00\',\r\n                1916-12-01 00:00:00+01:00],\r\n              dtype=\'datetime64[ns, Europe/Oslo]\', length=5, freq=\'1MS\')\r\n```\r\n\r\nThe problem is that 1916-10-01 00:00:00 is an ambiguous in Europe/Oslo as this is the DST transition, thus there are two possible UTC times  `1916-10-01 00:00:00+02:00` and `1916-10-01 00:00:00+01:00`. The ambiguous argument to `date_range` is not utilized.  \r\n\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 37ea63d540fd27274cad6585082c91b1283f963d\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.22621\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 165 Stepping 2, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\npandas           : 2.0.1\r\nnumpy            : 1.24.2\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.6.1\r\npip              : 23.0.1\r\nCython           : None\r\npytest           : 7.3.0\r\nhypothesis       : None\r\nsphinx           : 5.3.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.1.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.10.1\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52908/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52906',
#   'id': 1682243387,
#   'node_id': 'PR_kwDOAA0YD85PDhjc',
#   'number': 52906,
#   'title': 'DEPS: Address numpy deprecation of len 1 arrays assignment',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Required and optional dependencies'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-25T00:43:30Z',
#   'updated_at': '2023-04-25T00:43:30Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52906',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52906',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52906.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52906.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #52853 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52906/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52905',
#   'id': 1682045021,
#   'node_id': 'PR_kwDOAA0YD85PC2Tr',
#   'number': 52905,
#   'title': 'DOC: Remove versionadded/changed for 1.1.0',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T21:05:51Z',
#   'updated_at': '2023-04-25T00:49:07Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52905',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52905',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52905.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52905.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nremoved 1.0 and earlier for 2.0, so can remove 1.1.0 for 2.1 I guess',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52905/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52904',
#   'id': 1682019729,
#   'node_id': 'I_kwDOAA0YD85kQZWR',
#   'number': 52904,
#   'title': 'ENH: Support pyarrow timestamps in merge_asof',
#   'user': {'login': 'bphillips-exos',
#    'id': 56549508,
#    'node_id': 'MDQ6VXNlcjU2NTQ5NTA4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56549508?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bphillips-exos',
#    'html_url': 'https://github.com/bphillips-exos',
#    'followers_url': 'https://api.github.com/users/bphillips-exos/followers',
#    'following_url': 'https://api.github.com/users/bphillips-exos/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bphillips-exos/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bphillips-exos/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bphillips-exos/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bphillips-exos/orgs',
#    'repos_url': 'https://api.github.com/users/bphillips-exos/repos',
#    'events_url': 'https://api.github.com/users/bphillips-exos/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bphillips-exos/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T20:50:42Z',
#   'updated_at': '2023-04-25T02:29:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Feature Type\n\n- [X] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nI would like to be able to use pyarrow timestamp dtypes as the merge column/index in merge_asof operations.\r\n\r\nThis code currently raises `KeyError: 'timestamp[ns][pyarrow]_t|object'`\r\n```python\r\nimport pandas as pd\r\nimport pyarrow as pa\r\n\r\ndf = pd.DataFrame(\r\n    index=pd.Series([0, 1], dtype=pd.ArrowDtype(pa.timestamp('ns'))),\r\n    data={'value': pd.Series(['a', 'b'], dtype=pd.ArrowDtype(pa.string()))},\r\n)\r\n\r\npd.merge_asof(df, df, left_index=True, right_index=True)\r\n```\n\n### Feature Description\n\nThere would be no changes to user facing behavior, I'm not sure about the internal complexity involved in implementation. \n\n### Alternative Solutions\n\nThe current numpy datetime dtype can be used in merge_asof operations, but when your dataframe is read from parquet files this can be an expensive translation step. \n\n### Additional Context\n\n_No response_",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52904/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52903',
#   'id': 1681993470,
#   'node_id': 'PR_kwDOAA0YD85PCqzp',
#   'number': 52903,
#   'title': 'BUG: Fix pandas._libs.json __name__',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 26,
#    'closed_issues': 434,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-04-25T00:52:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-04-24T20:34:47Z',
#   'updated_at': '2023-04-24T20:34:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52903',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52903',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52903.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52903.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52898 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52903/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52902',
#   'id': 1681962231,
#   'node_id': 'PR_kwDOAA0YD85PCj0R',
#   'number': 52902,
#   'title': 'BUG: date_range with DateOffset with nanoseconds',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False,
#     'description': 'DateOffsets'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 26,
#    'closed_issues': 434,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-04-25T00:52:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-04-24T20:16:11Z',
#   'updated_at': '2023-04-24T22:28:19Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52902',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52902',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52902.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52902.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46877 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52902/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52899',
#   'id': 1681787303,
#   'node_id': 'I_kwDOAA0YD85kPgmn',
#   'number': 52899,
#   'title': '`pyarrow` uses `is_sparse()`, which is deprecated in development code, causing warnings on I/O routines with pandas',
#   'user': {'login': 'Dr-Irv',
#    'id': 15113894,
#    'node_id': 'MDQ6VXNlcjE1MTEzODk0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15113894?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dr-Irv',
#    'html_url': 'https://github.com/Dr-Irv',
#    'followers_url': 'https://api.github.com/users/Dr-Irv/followers',
#    'following_url': 'https://api.github.com/users/Dr-Irv/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Dr-Irv/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Dr-Irv/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Dr-Irv/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Dr-Irv/orgs',
#    'repos_url': 'https://api.github.com/users/Dr-Irv/repos',
#    'events_url': 'https://api.github.com/users/Dr-Irv/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Dr-Irv/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-24T18:11:20Z',
#   'updated_at': '2023-04-25T02:29:51Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': 'See tests from pandas-stubs:  https://github.com/pandas-dev/pandas-stubs/actions/runs/4789491663/jobs/8517432719\r\n\r\n`to_feather()`, `to_orc()` and `to_parquet()` call pyarrow, which is using `api.is_sparse()`, which is now marked as deprecated.\r\n\r\nCreated pandas-stubs issue:\r\nhttps://github.com/pandas-dev/pandas-stubs/issues/657\r\n\r\nComment here by @mroeschke in https://github.com/pandas-dev/pandas/pull/52642#discussion_r1167150428 indicates it is reasonable for pyarrow to change their code - checking if we have created an issue there, and whether we should do something about the warning that a user would see if using those methods from pandas.\r\n\r\n@jbrockmendel \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52899/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52898',
#   'id': 1681783699,
#   'node_id': 'I_kwDOAA0YD85kPfuT',
#   'number': 52898,
#   'title': 'BUG: Module `pandas._libs.json` has incorrect `__name__` attribute',
#   'user': {'login': 'shwina',
#    'id': 3190405,
#    'node_id': 'MDQ6VXNlcjMxOTA0MDU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3190405?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shwina',
#    'html_url': 'https://github.com/shwina',
#    'followers_url': 'https://api.github.com/users/shwina/followers',
#    'following_url': 'https://api.github.com/users/shwina/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shwina/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shwina/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shwina/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shwina/orgs',
#    'repos_url': 'https://api.github.com/users/shwina/repos',
#    'events_url': 'https://api.github.com/users/shwina/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shwina/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 49379259,
#     'node_id': 'MDU6TGFiZWw0OTM3OTI1OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20JSON',
#     'name': 'IO JSON',
#     'color': '207de5',
#     'default': False,
#     'description': 'read_json, to_json, json_normalize'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-24T18:08:44Z',
#   'updated_at': '2023-04-25T09:19:10Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n>>> import pandas as pd\r\npd>>> pd.__version__\r\n'2.0.0'\r\n>>> pd._libs.json.__name__\r\n'_libjson'\r\n>>> pd._libs.missing.__name__\r\n'pandas._libs.missing'\n```\n\n\n### Issue Description\n\nThe `__name__` attribute for the `pandas._libs.json` is set to `_libjson` [here](https://github.com/pandas-dev/pandas/blob/main/pandas/_libs/src/ujson/python/ujson.c#L86).\r\n\r\nThe [Python docs](https://docs.python.org/3/reference/import.html#name__) say that `__name__` should be set to the fully qualified name of the module, which I would expect to be `'pandas._libs.json'`.\r\n\r\nIn the code example above, you can see that other Pandas C-extensions like `pd._libs.missing` have the correct `__name__` attribute set.\r\n\n\n### Expected Behavior\n\n`__name__` should be set to the fully qualified name of the module, which I would expect to be `'pandas._libs.json'`.\n\n### Installed Versions\n\n2",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52898/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52897',
#   'id': 1681654482,
#   'node_id': 'PR_kwDOAA0YD85PBhHr',
#   'number': 52897,
#   'title': 'Fixes Incompatible return value type in pandas/core/generic.py',
#   'user': {'login': 'bunardsheng',
#    'id': 84961555,
#    'node_id': 'MDQ6VXNlcjg0OTYxNTU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84961555?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bunardsheng',
#    'html_url': 'https://github.com/bunardsheng',
#    'followers_url': 'https://api.github.com/users/bunardsheng/followers',
#    'following_url': 'https://api.github.com/users/bunardsheng/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bunardsheng/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bunardsheng/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bunardsheng/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bunardsheng/orgs',
#    'repos_url': 'https://api.github.com/users/bunardsheng/repos',
#    'events_url': 'https://api.github.com/users/bunardsheng/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bunardsheng/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T16:35:49Z',
#   'updated_at': '2023-04-24T20:50:00Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52897',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52897',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52897.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52897.patch',
#    'merged_at': None},
#   'body': '- Contributes to issue #37715 (https://github.com/pandas-dev/pandas/issues/37715)\r\n- Casts 64-bit signed integer to int value\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52897/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52895',
#   'id': 1681362435,
#   'node_id': 'I_kwDOAA0YD85kN44D',
#   'number': 52895,
#   'title': 'BUG: int Overflow with DateFormatter',
#   'user': {'login': 'joooeey',
#    'id': 28426758,
#    'node_id': 'MDQ6VXNlcjI4NDI2NzU4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28426758?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joooeey',
#    'html_url': 'https://github.com/joooeey',
#    'followers_url': 'https://api.github.com/users/joooeey/followers',
#    'following_url': 'https://api.github.com/users/joooeey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/joooeey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/joooeey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/joooeey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/joooeey/orgs',
#    'repos_url': 'https://api.github.com/users/joooeey/repos',
#    'events_url': 'https://api.github.com/users/joooeey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/joooeey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 3059772828,
#     'node_id': 'MDU6TGFiZWwzMDU5NzcyODI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/datetime.date',
#     'name': 'datetime.date',
#     'color': 'bfd4f2',
#     'default': False,
#     'description': 'stdlib datetime.date support'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-04-24T14:08:02Z',
#   'updated_at': '2023-04-25T02:31:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport datetime as dt\r\nfrom matplotlib import dates\r\nimport pandas as pd\r\n\r\ndates.set_epoch("2023-01-01")  # suggested workaround doesn\'t help\r\nstart = dt.datetime(2022, 4, 4, 7)\r\nend = dt.datetime(2022, 4, 4, 16)\r\nindex = pd.date_range(start, end, freq="s")\r\ndf = pd.DataFrame(index=index)\r\ndf["col"] = 1\r\nax = df.plot()\r\nax.xaxis.set_major_formatter(dates.DateFormatter("%H:%M"))  # breaks\n```\n\n\n### Issue Description\n\nSee also:  #18348\r\n\r\nWhen setting a `matplotlib.dates.DateFormatter`, I get the following exception:\r\n```\r\nOverflowError: int too big to convert\r\n```\r\n\r\nFull Traceback:\r\n\r\n<details>\r\n\r\n```\r\nrunfile(\'/home/lukas/.config/spyder-py3/temp.py\', wdir=\'/home/lukas/.config/spyder-py3\')\r\n[autoreload of pandas.core.arrays.timedeltas failed: Traceback (most recent call last):\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 273, in check\r\n    superreload(m, reload, self.old_objects)\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 471, in superreload\r\n    module = reload(module)\r\n             ^^^^^^^^^^^^^^\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/importlib/__init__.py", line 169, in reload\r\n    _bootstrap._exec(spec, module)\r\n  File "<frozen importlib._bootstrap>", line 621, in _exec\r\n  File "<frozen importlib._bootstrap_external>", line 940, in exec_module\r\n  File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/pandas/core/arrays/timedeltas.py", line 34, in <module>\r\n    from pandas._libs.tslibs.fields import (\r\nImportError: cannot import name \'get_timedelta_days\' from \'pandas._libs.tslibs.fields\' (/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/pandas/_libs/tslibs/fields.cpython-311-x86_64-linux-gnu.so)\r\n]\r\n[autoreload of pandas._testing failed: Traceback (most recent call last):\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 273, in check\r\n    superreload(m, reload, self.old_objects)\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 471, in superreload\r\n    module = reload(module)\r\n             ^^^^^^^^^^^^^^\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/importlib/__init__.py", line 169, in reload\r\n    _bootstrap._exec(spec, module)\r\n  File "<frozen importlib._bootstrap>", line 621, in _exec\r\n  File "<frozen importlib._bootstrap_external>", line 940, in exec_module\r\n  File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed\r\n  File "/home/lukas/mambaforge/envs/moma/lib/python3.11/site-packages/pandas/_testing/__init__.py", line 914, in <module>\r\n    cython_table = pd.core.common._cython_table.items()\r\n                   ^^^^^^^^^^^^^^\r\nAttributeError: module \'pandas.core\' has no attribute \'common\'\r\n]\r\nError in callback <function _draw_all_if_interactive at 0x7f4dc0f96020> (for post_execute):\r\nTraceback (most recent call last):\r\n\r\n  File ~/mambaforge/envs/moma/lib/python3.11/site-packages/matplotlib/pyplot.py:120 in _draw_all_if_interactive\r\n    draw_all()\r\n\r\n  File ~/mambaforge/envs/moma/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132 in draw_all\r\n    manager.canvas.draw_idle()\r\n\r\n  File ~/mambaforge/envs/moma ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52895/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52894/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52894',
#   'id': 1681244130,
#   'node_id': 'PR_kwDOAA0YD85PAHZS',
#   'number': 52894,
#   'title': 'added typing IntervalClosedType where needed',
#   'user': {'login': 'gmollard',
#    'id': 22834092,
#    'node_id': 'MDQ6VXNlcjIyODM0MDky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22834092?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gmollard',
#    'html_url': 'https://github.com/gmollard',
#    'followers_url': 'https://api.github.com/users/gmollard/followers',
#    'following_url': 'https://api.github.com/users/gmollard/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gmollard/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/gmollard/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gmollard/subscriptions',
#    'organizations_url': 'https://api.github.com/users/gmollard/orgs',
#    'repos_url': 'https://api.github.com/users/gmollard/repos',
# ...
#     'gists_url': 'https://api.github.com/users/szczekulskij/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/szczekulskij/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/szczekulskij/subscriptions',
#     'organizations_url': 'https://api.github.com/users/szczekulskij/orgs',
#     'repos_url': 'https://api.github.com/users/szczekulskij/repos',
#     'events_url': 'https://api.github.com/users/szczekulskij/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/szczekulskij/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2023-04-22T15:08:14Z',
#   'updated_at': '2023-04-25T01:52:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '```\r\ndf = DataFrame({"a1": [0, 0, 1], "a2": [2, 3, 3], "b": [4, 5, 6]})\r\ndf = df.astype({"a1": "category", "a2": "category"})\r\ngb = df.groupby(by=["a1", "a2"], as_index=False, observed=False)\r\ngb.nunique()\r\n```\r\n\r\nraises `ValueError: Length of values (3) does not match length of index (4)`',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52848/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52848/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52840',
#   'id': 1679191992,
#   'node_id': 'PR_kwDOAA0YD85O5dWS',
#   'number': 52840,
#   'title': 'BUG: FloatingArray.__contains__(nan)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-21T22:48:55Z',
#   'updated_at': '2023-04-24T18:33:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52840',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52840',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52840.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52840.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nMore targeted version of #51378',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52840/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52839',
#   'id': 1679005068,
#   'node_id': 'PR_kwDOAA0YD85O40H-',
#   'number': 52839,
#   'title': 'DEPR: Series logical ops with different index coercing to bool',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric%20Operations',
#     'name': 'Numeric Operations',
#     'color': '006b75',
#     'default': False,
#     'description': 'Arithmetic, Comparison, and Logical operations'},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 26,
#    'closed_issues': 434,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-04-25T00:52:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2023-04-21T19:44:35Z',
#   'updated_at': '2023-04-24T20:38:34Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52839',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52839',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52839.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52839.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52500 (Replace xxxx with the GitHub issue number)\r\n- [x] closes #52538 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52839/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52836',
#   'id': 1678956012,
#   'node_id': 'PR_kwDOAA0YD85O4pih',
#   'number': 52836,
#   'title': 'PERF: Faster transposition of frames with masked arrays',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-04-21T18:53:59Z',
#   'updated_at': '2023-04-22T01:08:34Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52836',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52836',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52836.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52836.patch',
#    'merged_at': None},
#   'body': 'Faster transpose of dataframes with homogenous masked arrays. This also helps when doing reductions with `axis=1` as those currently transpose data before doing reductions.\r\n\r\nPerformance example:\r\n\r\n```python\r\nIn [1]:         import pandas as pd, numpy as np\r\n   ...:         values = np.random.randn(100000, 4)\r\n   ...:         values = values.astype(int)\r\n   ...:         df = pd.DataFrame(values).astype("Int64")\r\n>>> %timeit df.transpose()\r\n1.91 s ± 3.08 ms per loop  # main\r\n563 ms ± 2.48 ms per loop  # this PR\r\n```\r\n\r\nRunning `asv continuous -f 1.1 upstream/main HEAD -b reshape.ReshapeMaskedArrayDtype.time_transpose`:\r\n\r\n```\r\n       before           after         ratio\r\n     [c3f0aac1]       [43162428]\r\n     <master>         <cln_managers>\r\n-     13.5±0.06ms      1.82±0.01ms     0.14  reshape.ReshapeMaskedArrayDtype.time_transpose(\'Float64\')\r\n-     13.8±0.03ms      1.83±0.01ms     0.13  reshape.ReshapeMaskedArrayDtype.time_transpose(\'Int64\')\r\n\r\nSOME BENCHMARKS HAVE CHANGED SIGNIFICANTLY.\r\nPERFORMANCE INCREASED.\r\n```\r\n\r\nThere may be possible to improve performance when frames have a common masked dtype, I intend to look into that in a followup.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52836/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
pd.DataFrame(d1,columns=['url','repository_url','labels_url','comments_url'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
data=d1[1]['user']['login']

# %%
data
# Out:
# 'mroeschke'
